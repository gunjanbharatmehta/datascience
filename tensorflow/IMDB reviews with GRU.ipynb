# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# 2.6.0
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK2UG62/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK2UG62/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK2UG62/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 54s 59ms/step - loss: 0.6125 - accuracy: 0.6328 - val_loss: 0.4213 - val_accuracy: 0.8140
# Epoch 2/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.3677 - accuracy: 0.8459 - val_loss: 0.3580 - val_accuracy: 0.8468
# Epoch 3/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.2767 - accuracy: 0.8928 - val_loss: 0.3678 - val_accuracy: 0.8436
# Epoch 4/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.2292 - accuracy: 0.9147 - val_loss: 0.3891 - val_accuracy: 0.8419
# Epoch 5/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1838 - accuracy: 0.9350 - val_loss: 0.3997 - val_accuracy: 0.8380
# Epoch 6/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1393 - accuracy: 0.9533 - val_loss: 0.4857 - val_accuracy: 0.8304
# Epoch 7/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.1048 - accuracy: 0.9664 - val_loss: 0.5716 - val_accuracy: 0.8263
# Epoch 8/50
# 782/782 [==============================] - 45s 58ms/step - loss: 7.1795e-04 - accuracy: 0.9999 - val_loss: 1.6462 - val_accuracy: 0.8094
# Epoch 31/50
# 782/782 [==============================] - 45s 58ms/step - loss: 5.5384e-05 - accuracy: 1.0000 - val_loss: 1.7101 - val_accuracy: 0.8103
# Epoch 32/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.0838e-05 - accuracy: 1.0000 - val_loss: 1.8385 - val_accuracy: 0.8111
# Epoch 33/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.1395e-05 - accuracy: 1.0000 - val_loss: 1.9060 - val_accuracy: 0.8109
# Epoch 34/50
# 782/782 [==============================] - 45s 58ms/step - loss: 7.4921e-06 - accuracy: 1.0000 - val_loss: 1.9655 - val_accuracy: 0.8106
# Epoch 35/50
# 782/782 [==============================] - 45s 58ms/step - loss: 4.9671e-06 - accuracy: 1.0000 - val_loss: 2.0302 - val_accuracy: 0.8108
# Epoch 36/50
# 782/782 [==============================] - 45s 58ms/step - loss: 3.3191e-06 - accuracy: 1.0000 - val_loss: 2.0889 - val_accuracy: 0.8108
# Epoch 37/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.2134e-06 - accuracy: 1.0000 - val_loss: 2.1559 - val_accuracy: 0.8105
# Epoch 38/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.4701e-06 - accuracy: 1.0000 - val_loss: 2.2195 - val_accuracy: 0.8101
# Epoch 39/50
# 782/782 [==============================] - 45s 58ms/step - loss: 9.7164e-07 - accuracy: 1.0000 - val_loss: 2.2915 - val_accuracy: 0.8100
# Epoch 40/50
# 782/782 [==============================] - 45s 58ms/step - loss: 6.4634e-07 - accuracy: 1.0000 - val_loss: 2.3548 - val_accuracy: 0.8100
# Epoch 41/50
# 782/782 [==============================] - 45s 58ms/step - loss: 4.2692e-07 - accuracy: 1.0000 - val_loss: 2.4260 - val_accuracy: 0.8097
# Epoch 42/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.8282e-07 - accuracy: 1.0000 - val_loss: 2.4955 - val_accuracy: 0.8095
# Epoch 43/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.8734e-07 - accuracy: 1.0000 - val_loss: 2.5611 - val_accuracy: 0.8092
# Epoch 44/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.2458e-07 - accuracy: 1.0000 - val_loss: 2.6305 - val_accuracy: 0.8093
# Epoch 45/50
# 782/782 [==============================] - 45s 58ms/step - loss: 8.3437e-08 - accuracy: 1.0000 - val_loss: 2.6968 - val_accuracy: 0.8092
# Epoch 46/50
# 782/782 [==============================] - 45s 58ms/step - loss: 5.6043e-08 - accuracy: 1.0000 - val_loss: 2.7609 - val_accuracy: 0.8093
# Epoch 47/50
# 782/782 [==============================] - 45s 58ms/step - loss: 3.7910e-08 - accuracy: 1.0000 - val_loss: 2.8321 - val_accuracy: 0.8089
# Epoch 48/50
# 782/782 [==============================] - 45s 58ms/step - loss: 2.5908e-08 - accuracy: 1.0000 - val_loss: 2.8954 - val_accuracy: 0.8090
# Epoch 49/50
# 782/782 [==============================] - 46s 58ms/step - loss: 1.7812e-08 - accuracy: 1.0000 - val_loss: 2.9601 - val_accuracy: 0.8088
# Epoch 50/50
# 782/782 [==============================] - 45s 58ms/step - loss: 1.2406e-08 - accuracy: 1.0000 - val_loss: 3.0202 - val_accuracy: 0.8090

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
